# %%
import coremltools
# %load_ext autoreload
# %autoreload 2

# %%
from keras.models import load_model
model = load_model('./model/nn4.small2.v5.h5')
# Out:
# /Users/victor_sy_wang/anaconda/lib/python2.7/site-packages/keras/models.py:245: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
model.layers[1].layers
# Out:
# [<keras.layers.convolutional.ZeroPadding2D at 0x117373ed0>,
#  <keras.layers.convolutional.Conv2D at 0x117373f90>,
#  <keras.layers.normalization.BatchNormalization at 0x1174c35d0>,
#  <keras.layers.core.Activation at 0x11762c310>,
#  <keras.layers.convolutional.ZeroPadding2D at 0x1175ee410>,
#  <keras.layers.pooling.MaxPooling2D at 0x117669e10>,
#  <keras.layers.convolutional.Conv2D at 0x1174f4c50>,
#  <keras.layers.normalization.BatchNormalization at 0x1176c9bd0>,
#  <keras.layers.core.Activation at 0x11767a650>,
#  <keras.layers.convolutional.ZeroPadding2D at 0x1177c0e90>,
#  <keras.layers.convolutional.Conv2D at 0x1177ee550>,
#  <keras.layers.normalization.BatchNormalization at 0x11773bc10>,
#  <keras.layers.core.Activation at 0x1178de3d0>,
#  <keras.layers.convolutional.ZeroPadding2D at 0x11786c5d0>,
#  <keras.layers.pooling.MaxPooling2D at 0x1179907d0>]

# %%
coreml_model = coremltools.converters.keras.convert(model)
# Out:
# 0 : input_2, <keras.engine.topology.InputLayer object at 0x122575450>
# 1 : zero_padding2d_6, <keras.layers.convolutional.ZeroPadding2D object at 0x122575510>
# 2 : conv1, <keras.layers.convolutional.Conv2D object at 0x122575e50>
# 3 : conv1_permute_bn1, <keras.layers.core.Permute object at 0x12919d390>
# 4 : bn1, <keras.layers.normalization.BatchNormalization object at 0x1225758d0>
# 5 : bn1_permute_activation_6, <keras.layers.core.Permute object at 0x126f72f50>
# 6 : activation_6, <keras.layers.core.Activation object at 0x122575f50>
# 7 : zero_padding2d_7, <keras.layers.convolutional.ZeroPadding2D object at 0x122767bd0>
# 8 : max_pooling2d_3, <keras.layers.pooling.MaxPooling2D object at 0x1226a8f90>
# 9 : conv2, <keras.layers.convolutional.Conv2D object at 0x1227daad0>
# 10 : conv2_permute_bn2, <keras.layers.core.Permute object at 0x12919d210>
# 11 : bn2, <keras.layers.normalization.BatchNormalization object at 0x122847e90>
# 12 : bn2_permute_activation_7, <keras.layers.core.Permute object at 0x10ddaad10>
# 13 : activation_7, <keras.layers.core.Activation object at 0x122873190>
# 14 : zero_padding2d_8, <keras.layers.convolutional.ZeroPadding2D object at 0x1229d0490>
# 15 : conv3, <keras.layers.convolutional.Conv2D object at 0x122861410>
# 16 : conv3_permute_bn3, <keras.layers.core.Permute object at 0x10ddaad50>
# 17 : bn3, <keras.layers.normalization.BatchNormalization object at 0x1228f0f10>
# 18 : bn3_permute_activation_8, <keras.layers.core.Permute object at 0x12689dc90>
# 19 : activation_8, <keras.layers.core.Activation object at 0x122a3a510>
# 20 : zero_padding2d_9, <keras.layers.convolutional.ZeroPadding2D object at 0x122aa85d0>
# 21 : max_pooling2d_4, <keras.layers.pooling.MaxPooling2D object at 0x122a7b610>
# 22 : inception_3a_3x3_conv1, <keras.layers.convolutional.Conv2D object at 0x122ba6c90>
# 23 : inception_3a_5x5_conv1, <keras.layers.convolutional.Conv2D object at 0x122b754d0>
# 24 : inception_3a_3x3_conv1_permute_inception_3a_3x3_bn1, <keras.layers.core.Permute object at 0x10ddaa3d0>
# 25 : inception_3a_3x3_bn1, <keras.layers.normalization.BatchNormalization object at 0x122bc4710>
# 26 : inception_3a_5x5_conv1_permute_inception_3a_5x5_bn1, <keras.layers.core.Permute object at 0x127493d10>
# 27 : inception_3a_5x5_bn1, <keras.layers.normalization.BatchNormalization object at 0x122be2750>
# 28 : inception_3a_3x3_bn1_permute_activation_9, <keras.layers.core.Permute object at 0x127493690>
# 29 : activation_9, <keras.layers.core.Activation object at 0x122cfdad0>
# 30 : inception_3a_5x5_bn1_permute_activation_11, <keras.layers.core.Permute object at 0x126b30210>
# 31 : activation_11, <keras.layers.core.Activation object at 0x122d5a950>
# 32 : max_pooling2d_5, <keras.layers.pooling.MaxPooling2D object at 0x122e47c10>
# 33 : zero_padding2d_10, <keras.layers.convolutional.ZeroPadding2D object at 0x122de4410>
# 34 : zero_padding2d_11, <keras.layers.convolutional.ZeroPadding2D object at 0x122ea4ad0>
# 35 : inception_3a_pool_conv, <keras.layers.convolutional.Conv2D object at 0x122ec3b50>
# 36 : inception_3a_3x3_conv2, <keras.layers.convolutional.Conv2D object at 0x122efff90>
# 37 : inception_3a_5x5_conv2, <keras.layers.convolutional.Conv2D object at 0x122f0edd0>
# 38 : inception_3a_pool_conv_permute_inception_3a_pool_bn, <keras.layers.core.Permute object at 0x126b30dd0>
# 39 : inception_3a_pool_bn, <keras.layers.normalization.BatchNormalization object at 0x122f2fd50>
# 40 : inception_3a_1x1_conv, <keras.layers.convolutional.Conv2D object at 0x122f8b9d0>
# 41 : inception_3a_3x3_conv2_permute_inception_3a_3x3_bn2, <keras.layers.core.Permute object at 0x126b99e50>
# 42 : inception_3a_3x3_bn2, <keras.layers.normalization.BatchNormalization object at 0x123036910>
# 43 : inception_3a_5x5_conv2_permute_inception_3a_5x5_bn2, <keras.layers.core.Permute object at 0x126b99f50>
# 44 : inception_3a_5x5_bn2, <keras.layers.normalization.BatchNormalization object at 0x123116050>
# 45 : inception_3a_pool_bn_permute_activation_13, <keras.layers.core.Permute object at 0x126b99cd0>
# 46 : activation_13, <keras.layers.core.Activation object at 0x1232a0550>
# 47 : inception_3a_1x1_conv_permute_inception_3a_1x1_bn, <keras.layers.core.Permute object at 0x126b99f90>
# 48 : inception_3a_1x1_bn, <keras.layers.normalization.BatchNormalization object at 0x1231be310>
# 49 : inception_3a_3x3_bn2_permute_activation_10, <keras.layers.core.Permute object at 0x126b99c10>
# 50 : activation_10, <keras.layers.core.Activation object at 0x123409610>
# 51 : inception_3a_5x5_bn2_permute_activation_12, <keras.layers.core.Permute object at 0x126b99fd0>
# 52 : activation_12, <keras.layers.core.Activation object at 0x1234d69d0>
# 53 : zero_padding2d_12, <keras.layers.convolutional.ZeroPadding2D object at 0x123533310>
# 54 : inception_3a_1x1_bn_permute_activation_14, <keras.layers.core.Permute object at 0x126b99bd0>
# 55 : activation_14, <keras.layers.core.Activation object at 0x1233f8c50>
# 56 : concatenate_1, <keras.layers.merge.Concatenate object at 0x1235512d0>
# ('fuck you', <keras.layers.merge.Concatenate object at 0x1235512d0>, [(None, 128, 12, 12), (None, 32, 12, 12), (None, 32, 12, 12), (None, 64, 12, 12)], 1)
# 57 : inception_3b_3x3_conv1, <keras.layers.convolutional.Conv2D object at 0x123492f10>
# 58 : inception_3b_5x5_conv1, <keras.layers.convolutional.Conv2D object at 0x123417ed0>
# 59 : inception_3b_3x3_conv1_permute_inception_3b_3x3_bn1, <keras.layers.core.Permute object at 0x126b99b90>
# 60 : inception_3b_3x3_bn1, <keras.layers.normalization.BatchNormalization object at 0x12358f950>
# 61 : inception_3b_5x5_conv1_permute_inception_3b_5x5_bn1, <keras.layers.core.Permute object at 0x1226004d0>
# 62 : inception_3b_5x5_bn1, <keras.layers.normalization.BatchNormalization object at 0x12358fc50>
# 63 : inception_3b_3x3_bn1_permute_activation_15, <keras.layers.core.Permute object at 0x122600590>
# 64 : activation_15, <keras.layers.core.Activation object at 0x12371a350>
# 65 : inception_3b_5x5_bn1_permute_activation_17, <keras.layers.core.Permute object at 0x122600290>
# 66 : activation_17, <keras.layers.core.Activation object at 0x123885410>
# 67 : average_pooling2d_1, <keras.layers.pooling.AveragePooling2D object at 0x123893cd0>
# 68 : zero_padding2d_13, <keras.layers.convolutional.ZeroPadding2D object at 0x1237b2150>
# 69 : zero_padding2d_14, <keras.layers.convolutional.ZeroPadding2D object at 0x12362a190>
# 70 : inception_3b_pool_conv, <keras.layers.convolutional.Conv2D object at 0x123738e90>
# 71 : inception_3b_3x3_conv2, <keras.layers.convolutional.Conv2D object at 0x12392cfd0>
# 72 : inception_3b_5x5_conv2, <keras.layers.convolutional.Conv2D object at 0x1238f0f90>
# 73 : inception_3b_pool_conv_permute_inception_3b_pool_bn, <keras.layers.core.Permute object at 0x122600050>
# 74 : inception_3b_pool_bn, <keras.layers.normalization.BatchNormalization object at 0x1239d9b10>
# 75 : inception_3b_1x1_conv, <keras.layers.convolutional.Conv2D object at 0x12390e090>
# 76 : inception_3b_3x3_conv2_permute_inception_3b_3x3_bn2, <keras.layers.core.Permute object at 0x1226002d0>
# 77 : inception_3b_3x3_bn2, <keras.layers.normalization.BatchNormalization object at 0x123ab2650>
# 78 : inception_3b_5x5_conv2_permute_inception_3b_5x5_bn2, <keras.layers.core.Permute object at 0x122600550>
# 79 : inception_3b_5x5_bn2, <keras.layers.normalization.BatchNormalization object at 0x123a82950>
# 80 : inception_3b_pool_bn_permute_activation_19, <keras.layers.core.Permute object at 0x122600b10>
# 81 : activation_19, <keras.layers.core.Activation object at 0x123cdf2d0>
# 82 : inception_3b_1x1_conv_permute_inception_3b_1x1_bn, <keras.layers.core.Permute object at 0x122600790>
# 83 : inception_3b_1x1_bn, <keras.layers.normalization.BatchNormalization object at 0x123e19390>
# 84 : inception_3b_3x3_bn2_permute_activation_16, <keras.layers.core.Permute object at 0x122600190>
# 85 : activation_16, <keras.layers.core.Activation object at 0x123e27f90>
# 86 : inception_3b_5x5_bn2_permute_activation_18, <keras.layers.core.Permute object at 0x122600350>
# 87 : activation_18, <keras.layers.core.Activation object at 0x123ea2910>
# 88 : zero_padding2d_15, <keras.layers.convolutional.ZeroPadding2D object at 0x123ec4050>
# 89 : inception_3b_1x1_bn_permute_activation_20, <keras.layers.core.Permute object at 0x1226005d0>
# 90 : activation_20, <keras.layers.core.Activation object at 0x123e56390>
# 91 : concatenate_2, <keras.layers.merge.Concatenate object at 0x123f34e50>
# ('fuck you', <keras.layers.merge.Concatenate object at 0x123f34e50>, [(None, 128, 12, 12), (None, 64, 12, 12), (None, 64, 12, 12), (None, 64, 12, 12)], 1)
# 92 : inception_3c_3x3_conv1, <keras.layers.convolutional.Conv2D object at 0x123f24fd0>
# 93 : inception_3c_5x5_conv1, <keras.layers.convolutional.Conv2D object at 0x123f62e50>
# 94 : inception_3c_3x3_conv1_permute_inception_3c_3x3_bn1, <keras.layers.core.Permute object at 0x122600910>
# 95 : inception_3c_3x3_bn1, <keras.layers.normalization.BatchNormalization object at 0x123fa1790>
# 96 : inception_3c_5x5_conv1_permute_inception_3c_5x5_bn1, <keras.layers.core.Permute object at 0x122600650>
# 97 : inception_3c_5x5_bn1, <keras.layers.normalization.BatchNormalization object at 0x123fd2710>
# 98 : inception_3c_3x3_bn1_permute_activation_21, <keras.layers.core.Permute object at 0x122600710>
# 99 : activation_21, <keras.layers.core.Activation object at 0x12406a310>
# 100 : inception_3c_5x5_bn1_permute_activation_23, <keras.layers.core.Permute object at 0x122600110>
# 101 : activation_23, <keras.layers.core.Activation object at 0x1242551d0>
# 102 : zero_padding2d_16, <keras.layers.convolutional.ZeroPadding2D object at 0x1242c4150>
# 103 : zero_padding2d_17, <keras.layers.convolutional.ZeroPadding2D object at 0x12416a750>
# 104 : inception_3c_3x3_conv2, <keras.layers.convolutional.Conv2D object at 0x1242d2d90>
# 105 : inception_3c_5x5_conv2, <keras.layers.convolutional.Conv2D object at 0x1241c41d0>
# 106 : inception_3c_3x3_conv2_permute_inception_3c_3x3_bn2, <keras.layers.core.Permute object at 0x122600490>
# 107 : inception_3c_3x3_bn2, <keras.layers.normalization.BatchNormalization object at 0x1242b2c90>
# 108 : inception_3c_5x5_conv2_permute_inception_3c_5x5_bn2, <keras.layers.core.Permute object at 0x122600a50>
# 109 : inception_3c_5x5_bn2, <keras.layers.normalization.BatchNormalization object at 0x1243793d0>
# 110 : max_pooling2d_6, <keras.layers.pooling.MaxPooling2D object at 0x124398b90>
# 111 : inception_3c_3x3_bn2_permute_activation_22, <keras.layers.core.Permute object at 0x122600810>
# 112 : activation_22, <keras.layers.core.Activation object at 0x124488dd0>
# 113 : inception_3c_5x5_bn2_permute_activation_24, <keras.layers.core.Permute object at 0x122600890>
# 114 : activation_24, <keras.layers.core.Activation object at 0x1245d17d0>
# 115 : zero_padding2d_18, <keras.layers.convolutional.ZeroPadding2D object at 0x1244a5450>
# 116 : concatenate_3, <keras.layers.merge.Concatenate object at 0x1245e0ed0>
# ('fuck you', <keras.layers.merge.Concatenate object at 0x1245e0ed0>, [(None, 256, 6, 6), (None, 64, 6, 6), (None, 320, 6, 6)], 1)
# 117 : inception_4a_3x3_conv1, <keras.layers.convolutional.Conv2D object at 0x1245f1c90>
# 118 : inception_4a_5x5_conv1, <keras.layers.convolutional.Conv2D object at 0x12460f6d0>
# 119 : inception_4a_3x3_conv1_permute_inception_4a_3x3_bn1, <keras.layers.core.Permute object at 0x122600950>
# 120 : inception_4a_3x3_bn1, <keras.layers.normalization.BatchNormalization object at 0x1245b1e50>
# 121 : inception_4a_5x5_conv1_permute_inception_4a_5x5_bn1, <keras.layers.core.Permute object at 0x122600450>
# 122 : inception_4a_5x5_bn1, <keras.layers.normalization.BatchNormalization object at 0x12464b8d0>
# 123 : inception_4a_3x3_bn1_permute_activation_25, <keras.layers.core.Permute object at 0x1226009d0>
# 124 : activation_25, <keras.layers.core.Activation object at 0x124777b10>
# 125 : inception_4a_5x5_bn1_permute_activation_27, <keras.layers.core.Permute object at 0x126448e90>
# 126 : activation_27, <keras.layers.core.Activation object at 0x1247d59d0>
# 127 : average_pooling2d_2, <keras.layers.pooling.AveragePooling2D object at 0x12492e190>
# 128 : zero_padding2d_19, <keras.layers.convolutional.ZeroPadding2D object at 0x1248a2b10>
# 129 : zero_padding2d_20, <keras.layers.convolutional.ZeroPadding2D object at 0x124743cd0>
# 130 : inception_4a_pool_conv, <keras.layers.convolutional.Conv2D object at 0x1248d4950>
# 131 : inception_4a_3x3_conv2, <keras.layers.convolutional.Conv2D object at 0x124969e50>
# 132 : inception_4a_5x5_conv2, <keras.layers.convolutional.Conv2D object at 0x124979910>
# 133 : inception_4a_pool_conv_permute_inception_4a_pool_bn, <keras.layers.core.Permute object at 0x126448e50>
# 134 : inception_4a_pool_bn, <keras.layers.normalization.BatchNormalization object at 0x12499a710>
# 135 : inception_4a_1x1_conv, <keras.layers.convolutional.Conv2D object at 0x124a61e50>
# 136 : inception_4a_3x3_conv2_permute_inception_4a_3x3_bn2, <keras.layers.core.Permute object at 0x126448f10>
# 137 : inception_4a_3x3_bn2, <keras.layers.normalization.BatchNormalization object at 0x124b90e90>
# 138 : inception_4a_5x5_conv2_permute_inception_4a_5x5_bn2, <keras.layers.core.Permute object at 0x126448fd0>
# 139 : inception_4a_5x5_bn2, <keras.layers.normalization.BatchNormalization object at 0x124a23ed0>
# 140 : inception_4a_pool_bn_permute_activation_29, <keras.layers.core.Permute object at 0x126448f50>
# 141 : activation_29, <keras.layers.core.Activation object at 0x124d0b590>
# 142 : inception_4a_1x1_conv_permute_inception_4a_1x1_bn, <keras.layers.core.Permute object at 0x12774d110>
# 143 : inception_4a_1x1_bn, <keras.layers.normalization.BatchNormalization object at 0x124e08890>
# 144 : inception_4a_3x3_bn2_permute_activation_26, <keras.layers.core.Permute object at 0x126448e10>
# 145 : activation_26, <keras.layers.core.Activation object at 0x124d1a410>
# 146 : inception_4a_5x5_bn2_permute_activation_28, <keras.layers.core.Permute object at 0x12774d850>
# 147 : activation_28, <keras.layers.core.Activation object at 0x124f44a10>
# 148 : zero_padding2d_21, <keras.layers.convolutional.ZeroPadding2D object at 0x124fa0350>
# 149 : inception_4a_1x1_bn_permute_activation_30, <keras.layers.core.Permute object at 0x12642a090>
# 150 : activation_30, <keras.layers.core.Activation object at 0x124e534d0>
# 151 : concatenate_4, <keras.layers.merge.Concatenate object at 0x124e83f10>
# ('fuck you', <keras.layers.merge.Concatenate object at 0x124e83f10>, [(None, 192, 6, 6), (None, 64, 6, 6), (None, 128, 6, 6), (None, 256, 6, 6)], 1)
# 152 : inception_4e_3x3_conv1, <keras.layers.convolutional.Conv2D object at 0x124efdf50>
# 153 : inception_4e_5x5_conv1, <keras.layers.convolutional.Conv2D object at 0x124faf8d0>
# 154 : inception_4e_3x3_conv1_permute_inception_4e_3x3_bn1, <keras.layers.core.Permute object at 0x12642a050>
# 155 : inception_4e_3x3_bn1, <keras.layers.normalization.BatchNormalization object at 0x1250184d0>
# 156 : inception_4e_5x5_conv1_permute_inception_4e_5x5_bn1, <keras.layers.core.Permute object at 0x12642a150>
# 157 : inception_4e_5x5_bn1, <keras.layers.normalization.BatchNormalization object at 0x124f6f890>
# 158 : inception_4e_3x3_bn1_permute_activation_31, <keras.layers.core.Permute object at 0x12642a190>
# 159 : activation_31, <keras.layers.core.Activation object at 0x125185350>
# 160 : inception_4e_5x5_bn1_permute_activation_33, <keras.layers.core.Permute object at 0x12642a3d0>
# 161 : activation_33, <keras.layers.core.Activation object at 0x1252be410>
# 162 : zero_padding2d_22, <keras.layers.convolutional.ZeroPadding2D object at 0x1252cecd0>
# 163 : zero_padding2d_23, <keras.layers.convolutional.ZeroPadding2D object at 0x1251ef150>
# 164 : inception_4e_3x3_conv2, <keras.layers.convolutional.Conv2D object at 0x125096190>
# 165 : inception_4e_5x5_conv2, <keras.layers.convolutional.Conv2D object at 0x1252de990>
# 166 : inception_4e_3x3_conv2_permute_inception_4e_3x3_bn2, <keras.layers.core.Permute object at 0x12642a1d0>
# 167 : inception_4e_3x3_bn2, <keras.layers.normalization.BatchNormalization object at 0x12531a990>
# 168 : inception_4e_5x5_conv2_permute_inception_4e_5x5_bn2, <keras.layers.core.Permute object at 0x12642a210>
# 169 : inception_4e_5x5_bn2, <keras.layers.normalization.BatchNormalization object at 0x1253a3ed0>
# 170 : max_pooling2d_7, <keras.layers.pooling.MaxPooling2D object at 0x1253d3e10>
# 171 : inception_4e_3x3_bn2_permute_activation_32, <keras.layers.core.Permute object at 0x12642a310>
# 172 : activation_32, <keras.layers.core.Activation object at 0x1253f0850>
# 173 : inception_4e_5x5_bn2_permute_activation_34, <keras.layers.core.Permute object at 0x12642a490>
# 174 : activation_34, <keras.layers.core.Activation object at 0x125455f50>
# 175 : zero_padding2d_24, <keras.layers.convolutional.ZeroPadding2D object at 0x12555cc50>
# 176 : concatenate_5, <keras.layers.merge.Concatenate object at 0x1255bcd10>
# ('fuck you', <keras.layers.merge.Concatenate object at 0x1255bcd10>, [(None, 256, 3, 3), (None, 128, 3, 3), (None, 640, 3, 3)], 1)
# 177 : inception_5a_3x3_conv1, <keras.layers.convolutional.Conv2D object at 0x1256497d0>
# 178 : inception_5a_3x3_conv1_permute_inception_5a_3x3_bn1, <keras.layers.core.Permute object at 0x12642a450>
# 179 : inception_5a_3x3_bn1, <keras.layers.normalization.BatchNormalization object at 0x1255afc50>
# 180 : inception_5a_3x3_bn1_permute_activation_35, <keras.layers.core.Permute object at 0x12642a590>
# 181 : activation_35, <keras.layers.core.Activation object at 0x12563cd10>
# 182 : average_pooling2d_3, <keras.layers.pooling.AveragePooling2D object at 0x1257751d0>
# 183 : zero_padding2d_25, <keras.layers.convolutional.ZeroPadding2D object at 0x1256861d0>
# 184 : inception_5a_pool_conv, <keras.layers.convolutional.Conv2D object at 0x125702450>
# 185 : inception_5a_3x3_conv2, <keras.layers.convolutional.Conv2D object at 0x1257c2c50>
# 186 : inception_5a_pool_conv_permute_inception_5a_pool_bn, <keras.layers.core.Permute object at 0x12642a550>
# 187 : inception_5a_pool_bn, <keras.layers.normalization.BatchNormalization object at 0x12584b410>
# 188 : inception_5a_1x1_conv, <keras.layers.convolutional.Conv2D object at 0x12582e910>
# 189 : inception_5a_3x3_conv2_permute_inception_5a_3x3_bn2, <keras.layers.core.Permute object at 0x12642a650>
# 190 : inception_5a_3x3_bn2, <keras.layers.normalization.BatchNormalization object at 0x1259b7290>
# 191 : inception_5a_pool_bn_permute_activation_37, <keras.layers.core.Permute object at 0x12642a690>
# 192 : activation_37, <keras.layers.core.Activation object at 0x1259f6ed0>
# 193 : inception_5a_1x1_conv_permute_inception_5a_1x1_bn, <keras.layers.core.Permute object at 0x12642a750>
# 194 : inception_5a_1x1_bn, <keras.layers.normalization.BatchNormalization object at 0x125ae3d10>
# 195 : inception_5a_3x3_bn2_permute_activation_36, <keras.layers.core.Permute object at 0x12642a790>
# 196 : activation_36, <keras.layers.core.Activation object at 0x125b70b90>
# 197 : zero_padding2d_26, <keras.layers.convolutional.ZeroPadding2D object at 0x125bfacd0>
# 198 : inception_5a_1x1_bn_permute_activation_38, <keras.layers.core.Permute object at 0x12642a910>
# 199 : activation_38, <keras.layers.core.Activation object at 0x125b5f590>
# 200 : concatenate_6, <keras.layers.merge.Concatenate object at 0x125b9c990>
# ('fuck you', <keras.layers.merge.Concatenate object at 0x125b9c990>, [(None, 384, 3, 3), (None, 96, 3, 3), (None, 256, 3, 3)], 1)
# 201 : inception_5b_3x3_conv1, <keras.layers.convolutional.Conv2D object at 0x125cbb7d0>
# 202 : inception_5b_3x3_conv1_permute_inception_5b_3x3_bn1, <keras.layers.core.Permute object at 0x12642a8d0>
# 203 : inception_5b_3x3_bn1, <keras.layers.normalization.BatchNormalization object at 0x125c41bd0>
# 204 : inception_5b_3x3_bn1_permute_activation_39, <keras.layers.core.Permute object at 0x12642a990>
# 205 : activation_39, <keras.layers.core.Activation object at 0x125cc9410>
# 206 : max_pooling2d_8, <keras.layers.pooling.MaxPooling2D object at 0x125da2790>
# 207 : zero_padding2d_27, <keras.layers.convolutional.ZeroPadding2D object at 0x125d04a90>
# 208 : inception_5b_pool_conv, <keras.layers.convolutional.Conv2D object at 0x125d53a10>
# 209 : inception_5b_3x3_conv2, <keras.layers.convolutional.Conv2D object at 0x125d94a90>
# 210 : inception_5b_pool_conv_permute_inception_5b_pool_bn, <keras.layers.core.Permute object at 0x12642a890>
# 211 : inception_5b_pool_bn, <keras.layers.normalization.BatchNormalization object at 0x125e13fd0>
# 212 : inception_5b_1x1_conv, <keras.layers.convolutional.Conv2D object at 0x125e9dc50>
# 213 : inception_5b_3x3_conv2_permute_inception_5b_3x3_bn2, <keras.layers.core.Permute object at 0x12642aa50>
# 214 : inception_5b_3x3_bn2, <keras.layers.normalization.BatchNormalization object at 0x1260453d0>
# 215 : inception_5b_pool_bn_permute_activation_41, <keras.layers.core.Permute object at 0x12642aa90>
# 216 : activation_41, <keras.layers.core.Activation object at 0x126083c50>
# 217 : inception_5b_1x1_conv_permute_inception_5b_1x1_bn, <keras.layers.core.Permute object at 0x12642ab50>
# 218 : inception_5b_1x1_bn, <keras.layers.normalization.BatchNormalization object at 0x1260d0890>
# 219 : inception_5b_3x3_bn2_permute_activation_40, <keras.layers.core.Permute object at 0x126c233d0>
# 220 : activation_40, <keras.layers.core.Activation object at 0x125fdbb10>
# 221 : zero_padding2d_28, <keras.layers.convolutional.ZeroPadding2D object at 0x1262ca8d0>
# 222 : inception_5b_1x1_bn_permute_activation_42, <keras.layers.core.Permute object at 0x126c23610>
# 223 : activation_42, <keras.layers.core.Activation object at 0x1261de190>
# 224 : concatenate_7, <keras.layers.merge.Concatenate object at 0x12632a990>
# ('fuck you', <keras.layers.merge.Concatenate object at 0x12632a990>, [(None, 384, 3, 3), (None, 96, 3, 3), (None, 256, 3, 3)], 1)
# 225 : average_pooling2d_4, <keras.layers.pooling.AveragePooling2D object at 0x12628be90>
# 226 : flatten_1, <keras.layers.core.Flatten object at 0x12634ba90>
# 227 : dense_layer, <keras.layers.core.Dense object at 0x1263391d0>

# %%
# Read a sample image as input to test the model
import cv2
import numpy as np
img = cv2.imread('./data/dlib-affine-sz/Aaron_Eckhart/Aaron_Eckhart_0001.png', 1)
img = img[...,::-1]
img = np.around(np.transpose(img, (2,0,1))/255.0, decimals=12)

x_train = np.array([img])
y = coreml_model.predict({'inpu1': x_train})
print y
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-11-25ded8ab9d94> in <module>()
#       7
#       8 x_train = np.array([img])
# ----> 9 y = coreml_model.predict({'inpu1': x_train})
#      10 print y
#
# /Users/victor_sy_wang/anaconda/lib/python2.7/site-packages/coremltools/models/model.pyc in predict(self, data, useCPUOnly, **kwargs)
#     242         else:
#     243             if _sys.platform != 'darwin' or float('.'.join(_platform.mac_ver()[0].split('.')[:2])) < 10.13:
# --> 244                 raise Exception('Model prediction is only supported on macOS version 10.13.')
#     245             else:
#     246                 raise Exception('Unable to load CoreML.framework. Cannot make predictions.')
#
# Exception: Model prediction is only supported on macOS version 10.13.
